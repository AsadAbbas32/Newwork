# %% [markdown]
# <a href="https://colab.research.google.com/github/AsadAbbas32/Newwork/blob/master/Haar_Feature.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %%
from google.colab.patches import cv2_imshow

# %%
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
# Read the input image
img = cv2.imread('download.jfif');
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces = face_cascade.detectMultiScale(gray, 1.1, 4)

for (x, y , w ,h) in faces:
    cv2.rectangle(img, (x,y), (x+w, y+h), (255, 0 , 0), 3)

# Display the output
cv2_imshow( img)
cv2.waitKey()
# Out:
# <PIL.Image.Image image mode=RGB size=329x153 at 0x7F8ABA6532D0>
# -1
